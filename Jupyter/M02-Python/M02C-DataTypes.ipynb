# %% [markdown]
# ![Cloud-First](https://github.com/tulip-lab/SIT742/blob/develop/Jupyter/image/CloudFirst.png?raw=1)
#
# # SIT742: Modern Data Science
# **(Module 02: Python Foundations for Big Data)**
#
# **Session 2C: Basic Data Types**
#
# ---
#
# - Materials in this module have been developed to support practical learning in modern data science, big data processing, and applied analytics.
# - Materials may include adapted or referenced open-source resources. Keep attribution and licence notes where applicable.
# - The public notebook collection is available in [SIT742](https://github.com/tulip-lab/sit742).
# - If you find any issue or bug in this document, please submit an issue at [SIT742](https://github.com/tulip-lab/sit742/issues).
# - Audience: Honours and Master’s students using the Deakin SIT742 practical and self-learning materials.
#
# Prepared by the SIT742 Teaching Team.
#
# Maintained through the [TULIP Lab](https://www.tulip.academy) FLIP workflow.
#
# ---
#
# <div align="center">
#
# <table>
# <thead>
# <tr>
# <th><strong>Item</strong></th>
# <th><strong>Description</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="left">Module context</td>
# <td>This notebook is one component of the practical and self-learning materials for this module. The full module is normally completed across two two-hour practical sessions, together with the other notebooks listed in the SIT742 repository.</td>
# </tr>
# <tr>
# <td align="left">Environment</td>
# <td>Google Colab, local Jupyter, or another Python 3 notebook environment</td>
# </tr>
# <tr>
# <td align="left">Main output</td>
# <td>A working notebook that demonstrates basic Python data types, conversion, comparison, and formatted output</td>
# </tr>
# <tr>
# <td align="left">Related assessment</td>
# <td>General practical skill development; not directly assessed</td>
# </tr>
# </tbody>
# </table>
#
# </div>
#
# ---
#
# **Table of Contents**
#
# - [1. Overview and Learning Goals](#1-overview-and-learning-goals)
# - [2. Setup and Background](#2-setup-and-background)
# - [3. Core Concepts](#3-core-concepts)
# - [4. Guided Examples](#4-guided-examples)
# - [5. Testing and Analysis](#5-testing-and-analysis)
# - [6. Student Tasks](#6-student-tasks)
# - [7. Reflection and References](#7-reflection-and-references)

# %% [markdown]
# <a id="1-overview-and-learning-goals"></a>
#
# ### 1. Overview and Learning Goals
#
# This session introduces Python's basic data types and the way those types affect simple expressions. You will practise strings, numbers, type conversion, comparison, logical operators, user input, and formatted output.
#
# By the end of this practical, you should be able to:
#
# 1. create and inspect string, integer, float, and Boolean values;
# 2. use Python operators for string manipulation and numeric calculation;
# 3. convert between compatible data types and recognise common conversion errors;
# 4. compare values and combine Boolean expressions with logical operators;
# 5. format simple output messages for a user.

# %% [markdown]
# <a id="2-setup-and-background"></a>
#
# ### 2. Setup and Background
#
# This notebook uses only standard Python. Run the setup cell below to confirm the Python version and working directory before continuing. No external dataset or package installation is required.

# %%
from pathlib import Path
import sys

print("Python version:", sys.version.split()[0])
print("Current working directory:", Path.cwd())
# Out:
# Python version: 3.12.13
# Current working directory: /content

# %% [markdown]
# <a id="3-core-concepts"></a>
#
# ### 3. Core Concepts
#
# Python attaches a type to every value. The type controls what operations are available and how Python interprets an expression.
#
# <div align="center">
#
# <table>
# <thead>
# <tr>
# <th><strong>Type</strong></th>
# <th><strong>Example</strong></th>
# <th><strong>Typical use</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="left">String</td>
# <td><code>'Hello'</code></td>
# <td>Text, labels, messages, file paths</td>
# </tr>
# <tr>
# <td align="left">Integer</td>
# <td><code>23</code></td>
# <td>Counts, indexes, whole-number quantities</td>
# </tr>
# <tr>
# <td align="left">Float</td>
# <td><code>45.6</code></td>
# <td>Measurements, proportions, decimal values</td>
# </tr>
# <tr>
# <td align="left">Boolean</td>
# <td><code>True</code> or <code>False</code></td>
# <td>Comparison results and decision logic</td>
# </tr>
# </tbody>
# </table>
#
# </div>
#
# Several examples below intentionally show errors or edge cases. They are labelled so you can distinguish expected errors from mistakes in your own work.

# %% [markdown]
# <a id="4-guided-examples"></a>
#
# ### 4. Guided Examples
#
# Work through the examples in order. The code cells preserve the original teaching sequence from the SIT742 Python foundations material, with extra notes around error-producing examples.

# %% [markdown]
# #### 4.1 Strings
#
# A string is a *sequence of characters*. We use strings in almost every Python program. Strings can be specified using single quotes or double quotes, and the `print()` function displays a string without the surrounding quotation marks.

# %%
print('Hello, World!')

# %% [markdown]
# We can also use a variable to store the string value, and use the variable in the
# **print()** function.

# %%
# Assign a string to a variable
text = 'Hello, World!'
print(text)

# %% [markdown]
# A *variable* is basically a name that represents (or refers to) some value. We use **=**
# to assign a value to a variable before we use it. Variable names are given by a programmer
# in a way that the program is easy to understanding. Variable names are *case sensitive*.
# It can consist of letters, digits and underscores. However, it can not begin with a digit.
# For example, **plan9** and **plan_9** are valid names, where **9plan** is not.

# %%
text = 'Hello, World!'

# %%
# with print() function, content is displayed without quotation mark
print(text)

# %% [markdown]
# With variables, we can also display its value without **print()** function. Note that
# you can not display a variable without **print()** function in Python script(i.e. in a **.py** file). This method only works under interactive mode (i.e. in the notebook).

# %%
# without print() function, quotation mark is displayed together with content
text

# %% [markdown]
# Quotation marks need careful handling. The following original example is intentionally shown as a non-executable snippet because it uses typographic apostrophes and mismatched quoting, which raises `SyntaxError: invalid character in identifier`.
#
# ```python
# text = ’What’ s your name ’
# ```
#
# Try to explain why Python cannot parse the line before opening the practice solution.

# %% [markdown]
# <details><summary><u><b><font color="Blue">Click here for a practice solution</font></b></u></summary>
#
# ```python
# text = 'What\'s your name?'
# print(text)
# ```
#
# The backslash escapes the apostrophe so Python treats it as part of the string rather than the end of the string.
#
# </details>

# %% [markdown]
# Since strings in double quotes **"** work exactly the same way as string in single quotes.
# By mixing the two types, it is easy to include quotation mark itself in the text.

# %%
text = "What' s your name?"
print(text)

# %% [markdown]
# Alternatively, you can use:

# %%
text = '"What is the problem?", he asked.'
print(text)

# %% [markdown]
# You can specify multi-line strings using triple quotes  (**"""** or **'''**). In this way, single
# quotes and double quotes can be used freely in the text.
# Here is one example:

# %%
multiline = '''This is a test for multiline. This is the first line.
This is the second line.
I asked, "What's your name?"'''
print(multiline)

# %% [markdown]
# Notice the difference when the variable is displayed without **print()** function in this case.

# %%
multiline = '''This is a test for multiline. This is the first line.
This is the second line.
I asked, "What's your name?"'''
multiline

# %% [markdown]
# Another way of include the special characters, such as single quotes is with help of
# escape sequences **\\**. For example, you can specify the single quote using **\\' ** as follows.

# %%
string = 'What\'s your name?'
print(string)

# %% [markdown]
# There are many more other escape sequences (See Section 2.4.1 in [Python3.0 official document](https://docs.python.org/3.1/reference/lexical_analysis.html)). But I am going to mention the most useful two examples here.
#
# First, use escape sequences to indicate the backslash itself e.g. **\\\\**

# %%
path = 'c:\\windows\\temp'
print(path)

# %% [markdown]
# Second,  used escape sequences to specify a two-line string. Apart from using a triple-quoted
# string as shown previously, you can use **\n** to indicate the start of a new line.

# %%
multiline = 'This is a test for multiline. This is the first line.\nThis is the second line.'
print(multiline)

# %% [markdown]
# To manipulate strings, the following two operators are most useful:
# * ** + ** is use to concatenate two strings or string variables;
# * ** * ** is used for concatenating several copies of the same string.

# %%
print('Hello, ' + 'World' * 3)
# Out:
# Hello, WorldWorldWorld

# %% [markdown]
# Below is another example of string concatenation based on  variables that store strings.

# %%
name = 'World'
greeting = 'Hello'
print(greeting + ', ' + name + '!')
# Out:
# Hello, World!

# %% [markdown]
# Using variables, change part of the string text is very easy.

# %%
name

# %%
greeting

# %%
# Change part of the text is easy
greeting = 'Good morning'
print(greeting + ', ' + name + '!')

# %% [markdown]
# #### 4.2 Numbers
#
# Python's two most common numeric types are integers and floats. Standard mathematical operators can be applied to both. The `**` operator performs exponentiation.

# %% [markdown]
# There are two types of numbers that are used most frequently: integers and floats. As we
# expect, the standard mathematical operation can be applied to these two types. Please
# try the following expressions. Note that **\*\*** is exponent operator, which indicates
# exponentiation exponential(power) calculation.

# %%
2 + 3

# %%
3 * 5

# %%
#3 to the power of 4
3 ** 4

# %% [markdown]
# Among the number operations, we need to look at division closely. In Python 3.0, classic division is performed using  **/**.

# %%
15 / 5

# %%
14 / 5

# %% [markdown]
# *//* is used to perform floor division. It truncates the fraction and rounds it to the next smallest whole number toward the left on the number line.

# %%
14 // 5

# %%
# Negatives move left on number line. The result is -3 instead of  -2
-14 // 5

# %% [markdown]
# Modulus operator **%** can be used to obtain remainder. Pay attention when negative number is involved.

# %%
14 % 5

# %%
# Hint:  −14 // 5 equal to −3
#        (-3) * 5 +  ? = -14

-14 % 5
# Out:
# 1

# %% [markdown]
# *Operator precedence* is a rule that affects how an expression is evaluated. As we learned in high school, the multiplication is done first than the addition. e.g. **2 + 3 * 4**. This means multiplication operator has higher precedence than the addition operator.
#
# For your reference, a precedence table from the python reference manual is used to indicate the evaluation order in Python.  For a complete precedence table, check the heading "Python Operators Precedence" in this [Python tutorial](http://www.tutorialspoint.com/python/python_basic_operators.htm)
#
#
# However, When things get confused, it is far better to use parentheses **()** to explicitly
# specify the precedence. This makes the program more readable.
#
# Here are some examples on operator precedence:

# %%
2 + 3 * 4
# Out:
# 14

# %%
(2 + 3) * 4

# %%
2 + 3 ** 2

# %%
(2 + 3) ** 2
# Out:
# 25

# %%
-(4+3)+2
# Out:
# -5

# %% [markdown]
# Similarly as string, variables can be used to store a number so that it is easy to manipulate them.

# %%
x = 3
y = 2
x + 2

# %%
sum = x + y
sum

# %%
x * y

# %% [markdown]
# One common expression is to run a math operation on a variable and then assign the result of the operation back to the variable. Therefore, there is a shortcut for such a expression.

# %%
x = 2
x = x * 3
x

# %% [markdown]
# This is equivalent to:

# %%
x = 2
# Note there is no space between '*' and '='
x *= 3
x
# Out:
# 6

# %% [markdown]
# #### 4.3 Data Conversion and Comparison
#
# Use `type()` to inspect a value's type. Use conversion functions such as `str()`, `int()`, and `float()` when a value needs to be represented as another compatible type.

# %% [markdown]
# So far, we have seen three types of data: integer, float, and string. With various data type, Python can define the operations possible on them and the storage method for each of them. In the later pracs, we will further introduce more data types, such as tuple, list and dictionary.
#
# To obtain the data type of a variable or a value, we can use built-in function **type()**;
# whereas functions, such as **str()**, **int()**, **float()**, are used to convert data one  type to another. Check the following examples on the usage of these functions:

# %%
type('Hello, world!)')
# Out:
# str

# %%
input_Value = '45.6'
type(input_Value)
# Out:
# str

# %%
weight = float(input_Value)
weight
type(weight)
# Out:
# float

# %% [markdown]
# Note the system will report error message when the conversion function is not compatible with the data.

# %%
input_Value = 'David'
try:
    weight = float(input_Value)
except ValueError as err:
    print(f"Expected conversion error: {err}")
weight = float(input_Value)
# Out:
# Expected conversion error: could not convert string to float: 'David'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_689/133909289.py in <cell line: 0>()
#       4 except ValueError as err:
#       5     print(f"Expected conversion error: {err}")
# ----> 6 weight = float(input_Value)
#       7
#       8
#
# ValueError: could not convert string to float: 'David'

# %% [markdown]
# Comparison between two values can help make decision in a program. The result of the comparison is either **True** or **False**. They are the two values of *Boolean* type.

# %%
5 > 10

# %%
type(5 > 10)

# %%
# Double equal sign is also used for comparison
10.0 == 10
# Out:
# True

# %% [markdown]
# Check the following examples on comparison of two strings.

# %%
'cat' > 'dog'
# Out:
# False

# %%
# All uppercases are smaller than low cases in terms of ASCII code. It will compare each character from the beginning to the end between two words based on their ACSII code value.
'cat' < 'Dog'
# Out:
# False

# %%
'apple' < 'apricot'

# %% [markdown]
# There are three logical operators, *not*, *and* and *or*, which can  be applied to the boolean values.

# %%
# Both condition #1 and condition #2 are True?
3 < 4  and 7 < 8
# Out:
# True

# %%
# Either condition 1 or condition 2 are True?
3 < 4  or 7 > 8
# Out:
# True

# %%
# Both conditional #1 and conditional #2 are False?
not ((3 > 4) or (7 > 8))
# Out:
# True

# %% [markdown]
# #### 4.4 Input and Output
#
# Python's `input()` function accepts user input as a string. In a live notebook, you can replace the sample value below with an interactive input prompt.

# %% [markdown]
# All programming languages provide features to interact with user. Python provide *input()* function to get input. It waits for the user to type some input and press return. We can add some information for the user by putting a message inside the function's brackets. It must be a string or a string variable. The text that was typed can be saved in a variable. Here is one example:

# %%
# In an interactive notebook, you can collect input with:
# nInput = input('Enter your number here:\n')

# This sample value keeps the notebook runnable during automated checks.
nInput = '5'
print(nInput)
type(nInput)
# Out:
# 5
# str

# %% [markdown]
# However, be aware that the input received from the user are treated as a string, even
# though a user entered a number. The following **print()** function invokes an error message.

# %%
try:
    print(nInput + 3)
except TypeError as err:
    print(f"Expected type error: {err}")
# Out:
# Expected type error: can only concatenate str (not "int") to str

# %% [markdown]
# The input need to be converted to an integer before the match operation can be performed as follows because the string data cannot add the integer data directly. They are totally different two types of data.

# %%
print(int(nInput) + 3)

# %% [markdown]
# After user's input are accepted, the messages need to be displayed to the user accordingly. String concatenation is one way to display messages which incorporate variable values.

# %%
name = 'David'
print('Hello, ' + name)

# %% [markdown]
# Another way of achieving this is using **print()** function with *string formatting*. We need to use the *string formatting operator*, the percent(**%**) sign.

# %%
name = 'David'
print('Hello, %s' % name)
# Out:
# Hello, David

# %% [markdown]
# Here is another example with two variables:

# %%
name = 'David'
age = 23
print('%s is %d years old.' % (name, age))
# Out:
# David is 23 years old.

# %% [markdown]
# Notice that the two variables, **name**, **age**, that specify the values are included at the end of the statement, and enclosed with a bracket.
#
# With the quotation mark,  **%s** and **%d** are used to specify formatting for string and integer respectively.
# The following table shows a selected set of symbols which can be used along with %.

# %% [markdown]
# <table width="304" border="1">
#   <tr>
#     <th width="112" scope="col">Format symbol</th>
#     <th width="176" scope="col">Conversion</th>
#   </tr>
#   <tr>
#     <td>%s</td>
#     <td>String</td>
#   </tr>
#   <tr>
#     <td>%d</td>
#     <td>Signed decimal integer</td>
#   </tr>
#   <tr>
#     <td>%f</td>
#     <td>Floating point real number</td>
#   </tr>
# </table>

# %% [markdown]
# There are extra characters that are used together with above symbols:

# %% [markdown]
# <table width="400" border="1">
#   <tr>
#     <th width="100" scope="col">Symbol</th>
#     <th width="3000" scope="col">Functionality</th>
#   </tr>
#   <tr>
#     <td>-</td>
#     <td>Left justification</td>
#   </tr>
#   <tr>
#     <td>+</td>
#     <td>Display the sign</td>
#   </tr>
#   <tr>
#     <td>m.n</td>
#     <td>m is the minimum total width; n is the number of digits to display after the decimal point</td>
#   </tr>
# </table>

# %% [markdown]
# Here are  more examples that use above specifiers:

# %%
# With %f, the format is right justification by default.
# As a result, white spaces are added to the left of the number
# 10.4 means minimal width 10 with 4 decimal points
print('Output a float number: %10.4f' % (3.5))
# Out:
# Output a float number:     3.5000

# %%
# plus sign after % means to show positive sign
# Zero after plus sign means using leading zero to fill width of 5
print('Output an integer: %+05d' % (23))
# Out:
# Output an integer: +0023

# %% [markdown]
# <a id="5-testing-and-analysis"></a>
#
# ### 5. Testing and Analysis
#
# Use small checks to confirm that your variables have the expected type and value. These are visible learning checks that help you reason about the examples.

# %%
examples = {
    "string": "Hello, World!",
    "integer": 23,
    "float": 45.6,
    "boolean": 5 > 10,
}

assert isinstance(examples["string"], str)    #assert is a test
assert isinstance(examples["integer"], int)
assert isinstance(examples["float"], float)
assert isinstance(examples["boolean"], bool)

print("All basic type checks passed.")
# Out:
# All basic type checks passed.

# %% [markdown]
# Normal case: compatible values can be converted and compared.
#
# Edge case: negative floor division and modulus may feel surprising because Python rounds floor division down toward the left on the number line.
#
# Failure case: incompatible conversions, such as `float('David')`, should raise a clear error. Use the error message to diagnose whether the value or the conversion function is wrong.

# %% [markdown]
# <a id="6-student-tasks"></a>
#
# ### 6. Student Tasks
#
# Complete the tasks below in new cells or by adapting the examples above.
#
# <div align="center">
#
# <table>
# <thead>
# <tr>
# <th><strong>Task</strong></th>
# <th><strong>What you need to do</strong></th>
# <th><strong>Why it matters</strong></th>
# <th><strong>Expected evidence</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="left">Task 1</td>
# <td>Create one string, one integer, one float, and one Boolean value, then inspect each with <code>type()</code>.</td>
# <td>Data science code often fails when values have a different type from the one you assumed.</td>
# <td>A small table or four printed lines showing value and type.</td>
# </tr>
# <tr>
# <td align="left">Task 2</td>
# <td>Write two string examples: one using an escaped apostrophe and one using double quotes around text that contains an apostrophe.</td>
# <td>Text fields often contain punctuation, names, and quoted phrases.</td>
# <td>Two printed strings that display correctly.</td>
# </tr>
# <tr>
# <td align="left">Task 3</td>
# <td>Compare classic division, floor division, and modulus for a positive and a negative number.</td>
# <td>Remainders and floor division are common in indexing, grouping, and feature engineering.</td>
# <td>Four to six expressions plus a short note explaining the negative-number result.</td>
# </tr>
# <tr>
# <td align="left">Task 4</td>
# <td>Start with a string such as <code>'45.6'</code>, convert it to a float, and format it in a user-facing message.</td>
# <td>Notebook inputs, CSV values, and form inputs often arrive as strings.</td>
# <td>A formatted message that includes the converted numeric value.</td>
# </tr>
# </tbody>
# </table>
#
# </div>

# %% [markdown]
# <a id="7-reflection-and-references"></a>
#
# ### 7. Reflection and References
#
# Reflection questions:
#
# 1. Which Python data type caused the most surprising behaviour in this notebook, and why?
# 2. What error message from the notebook would help you debug a future data-cleaning problem?
# 3. How would incorrect type conversion affect a larger data science workflow?
#
# #### Further Readings
#
# - [Python documentation: Built-in types](https://docs.python.org/3/library/stdtypes.html)
# - [Python documentation: Built-in functions](https://docs.python.org/3/library/functions.html)
# - [Python documentation: Lexical analysis and string literals](https://docs.python.org/3/reference/lexical_analysis.html#string-and-bytes-literals)
